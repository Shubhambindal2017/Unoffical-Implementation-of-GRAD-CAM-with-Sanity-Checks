# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

dir = '/content/drive/My Drive/Interpretability Research/imagenet_val/'

zip_list = os.listdir(dir)

print(len(zip_list))
# Out:
# 1001

# %%
import random

# %%
selected_zip_list = random.sample(zip_list, 50)

# %%
selected_zip_list
# Out:
# ['n02101556.tar',
#  'n07717556.tar',
#  'n04200800.tar',
#  'n02074367.tar',
#  'n03028079.tar',
#  'n04154565.tar',
#  'n07715103.tar',
#  'n02088238.tar',
#  'n01729977.tar',
#  'n07695742.tar',
#  'n02504013.tar',
#  'n02051845.tar',
#  'n03776460.tar',
#  'n03240683.tar',
#  'n04356056.tar',
#  'n02106166.tar',
#  'n02086910.tar',
#  'n01532829.tar',
#  'n03873416.tar',
#  'n01751748.tar',
#  'n12620546.tar',
#  'n03706229.tar',
#  'n02093754.tar',
#  'n04040759.tar',
#  'n02172182.tar',
#  'n02096294.tar',
#  'n02090721.tar',
#  'n03961711.tar',
#  'n03095699.tar',
#  'n02777292.tar',
#  'n03594945.tar',
#  'n04479046.tar',
#  'n04179913.tar',
#  'n01440764.tar',
#  'n02104365.tar',
#  'n02690373.tar',
#  'n02981792.tar',
#  'n04604644.tar',
#  'n04252077.tar',
#  'n04325704.tar',
#  'n03982430.tar',
#  'n02823428.tar',
#  'n07742313.tar',
#  'n03743016.tar',
#  'n02837789.tar',
#  'n07760859.tar',
#  'n04118538.tar',
#  'n04049303.tar',
#  'n03492542.tar',
#  'n04263257.tar']

# %%
# %mkdir '/content/Images'

# %%
# %cd '/content/drive/My Drive/Interpretability Research/imagenet_val/'
# Out:
# /content/drive/.shortcut-targets-by-id/157/imagenet_val

# %%
for i in selected_zip_list:

  # !tar -C /content/Images -xvf $i
# Out:
# Streaming output truncated to the last 5000 lines.
# n04118538_1968.JPEG
# n04118538_4150.JPEG
# n04118538_2724.JPEG
# n04118538_3294.JPEG
# n04118538_9030.JPEG
# n04118538_3878.JPEG
# n04118538_15132.JPEG
# n04118538_4834.JPEG
# n04118538_4282.JPEG
# n04118538_2100.JPEG
# n04118538_570.JPEG
# n04118538_7146.JPEG
# n04118538_2786.JPEG
# n04118538_12341.JPEG
# n04118538_14967.JPEG
# n04118538_772.JPEG
# n04118538_1461.JPEG
# n04118538_6006.JPEG
# n04118538_1988.JPEG
# n04118538_4267.JPEG
# n04118538_7916.JPEG
# n04118538_5965.JPEG
# n04118538_7361.JPEG
# n04118538_4525.JPEG
# n04118538_4484.JPEG
# n04118538_15047.JPEG
# n04118538_14394.JPEG
# n04118538_2200.JPEG
# n04118538_4057.JPEG
# n04118538_15848.JPEG
# n04118538_3066.JPEG
# n04118538_7192.JPEG
# n04118538_9010.JPEG
# n04118538_14975.JPEG
# n04118538_4178.JPEG
# n04118538_8876.JPEG
# n04118538_9708.JPEG
# n04118538_4884.JPEG
# n04118538_9015.JPEG
# n04118538_37.JPEG
# n04118538_2204.JPEG
# n04118538_3413.JPEG
# ...

# %%
import os, random

images_list = os.listdir('/content/Images')

selected_images_list = random.sample(images_list, 50)

# %%
# %mkdir '/content/drive/My Drive/Interpretability Research/50_Random_Images'

# %cd '/content/drive/My Drive/Interpretability Research/50_Random_Images'

# %%
import cv2

img_dir = '/content/Images'
output_img_dir = '/content/drive/My Drive/Interpretability Research/50_Random_Images'

for img in selected_images_list:

  img_path = os.path.join(img_dir, img)
  # !cp $img_path '/content/drive/My Drive/Interpretability Research/50_Random_Images'

# %%
import os, random

def get_random_image(imagenet_dir, synset=None, image_index=None):

  if synset is None:
    zip_list = os.listdir(imagenet_dir)
    synset_tar = random.sample(zip_list, 1)[0]
    synset = synset_tar.split('.')[0]

  else:
    synset_tar = os.path.join(synset, '.tar')

  print(f'synset tar ----> {synset_tar}')
  print(synset_done)

  if synset_tar not in synset_tar_done:

    print(synset_tar)

    file = os.path.join('/content/Images', synset)
    os.makedirs(file, exist_ok=True)
    # !tar -C  $file -xvf $synset_tar
    synset_tar_done.append(synset_tar)

  print(synset_tar_done)

  if image_index is None:
    images_list = os.listdir(os.path.join('/content/Images', synset))
    image = random.sample(images_list, 1)[0]

  else:
    images_list = os.listdir(os.path.join('/content/Images', synset))
    images_list = sorted(images_list)
    image = images_list[image_index]
    #image = os.path.join(synset.split('.')[0], '_', image_index, '.JPEG')

  return image

synset_tar_done = []
imagenet_dir = '/content/drive/My Drive/Interpretability Research/imagenet_val/'

# %cd $imagenet_dir
os.makedirs('/content/Images', exist_ok = True)
# Out:
# /content/drive/.shortcut-targets-by-id/130/imagenet_val

# %%
image = get_random_image(imagenet_dir, synset=None, image_index=None)
print(image)
# Out:
# synset tar ----> n04286575.tar
# ['n02124075.tar']
# n04286575.tar
# n04286575_3322.JPEG
# n04286575_3894.JPEG
# n04286575_2636.JPEG
# n04286575_13486.JPEG
# n04286575_5121.JPEG
# n04286575_4714.JPEG
# n04286575_5138.JPEG
# n04286575_3969.JPEG
# n04286575_5047.JPEG
# n04286575_5142.JPEG
# n04286575_3796.JPEG
# n04286575_870.JPEG
# n04286575_2623.JPEG
# n04286575_5112.JPEG
# n04286575_17667.JPEG
# n04286575_3792.JPEG
# n04286575_5446.JPEG
# n04286575_6332.JPEG
# n04286575_6781.JPEG
# n04286575_5113.JPEG
# n04286575_5717.JPEG
# n04286575_121.JPEG
# n04286575_4923.JPEG
# n04286575_5185.JPEG
# n04286575_4875.JPEG
# n04286575_2317.JPEG
# n04286575_25078.JPEG
# n04286575_38750.JPEG
# n04286575_35780.JPEG
# n04286575_35421.JPEG
# n04286575_21179.JPEG
# n04286575_26544.JPEG
# n04286575_5001.JPEG
# n04286575_25255.JPEG
# n04286575_2039.JPEG
# n04286575_13236.JPEG
# n04286575_20996.JPEG
# n04286575_26134.JPEG
# n04286575_30976.JPEG
# n04286575_27475.JPEG
# n04286575_69.JPEG
# ...

# %%
len(os.listdir('/content/drive/My Drive/Interpretability Research/50_Random_Images'))
# Out:
# 50
